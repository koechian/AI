# %%
# !pip install gradio -q
# !pip install sentence-transformers -q
# !pip install nltk -q

import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
#      |████████████████████████████████| 11.6 MB 6.3 MB/s
#      |████████████████████████████████| 272 kB 43.4 MB/s
#      |████████████████████████████████| 213 kB 69.4 MB/s
#      |████████████████████████████████| 84 kB 3.0 MB/s
#      |████████████████████████████████| 54 kB 2.9 MB/s
#      |████████████████████████████████| 84 kB 1.7 MB/s
#      |████████████████████████████████| 106 kB 42.1 MB/s
#      |████████████████████████████████| 56 kB 1.2 MB/s
#      |████████████████████████████████| 2.3 MB 47.4 MB/s
#      |████████████████████████████████| 55 kB 1.3 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
#      |████████████████████████████████| 80 kB 4.1 MB/s
#      |████████████████████████████████| 68 kB 2.8 MB/s
#      |████████████████████████████████| 46 kB 3.0 MB/s
#      |████████████████████████████████| 4.1 MB 37.6 MB/s
#      |████████████████████████████████| 856 kB 53.1 MB/s
#      |████████████████████████████████| 593 kB 39.6 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done
#      |████████████████████████████████| 85 kB 3.0 MB/s
#      |████████████████████████████████| 5.5 MB 40.3 MB/s
#      |████████████████████████████████| 1.3 MB 46.8 MB/s
#      |████████████████████████████████| 163 kB 50.2 MB/s
#      |████████████████████████████████| 7.6 MB 38.6 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from nltk.corpus import stopwords
stop = stopwords.words('english')

from sklearn.metrics.pairwise import cosine_similarity

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('titles.csv')
df.head()
# Out:
#                                                title
# 0     Solving QBF Instances with Nested SAT Solvers.
# 1                      Multiscale Manifold Learning.
# 2  Online Transfer Learning for Differential Diag...
# 3  Logic Programming in Assumption-Based Argument...
# 4  Role-Aware Conformity Modeling and Analysis in...

# %%
sample = df.sample(50)

#reset index
sample = sample.reset_index(drop=True)
sample.head()
# Out:
#                                                title
# 0  CSSV: towards a realistic tool for statically ...
# 1    Lifelong Learning for Sentiment Classification.
# 2  Improving the Price of Anarchy for Selfish Rou...
# 3  Fine-grained incremental learning and multi-fe...
# 4      UrbanIt: Visualizing repositories everywhere.

# %%
# cleaning
sample['ctitle'] = sample['title'].str.replace('[^\w\s]','')
sample['ctitle'] = sample['ctitle'].str.replace('\d+', '')
sample['ctitle'] = sample['ctitle'].str.lower()

sample['ctitle'] = sample['ctitle'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
sample.head()
# Out:
#                                                title  \
# 0  CSSV: towards a realistic tool for statically ...
# 1    Lifelong Learning for Sentiment Classification.
# 2  Improving the Price of Anarchy for Selfish Rou...
# 3  Fine-grained incremental learning and multi-fe...
# 4      UrbanIt: Visualizing repositories everywhere.
#
#                                               ctitle
# 0  cssv towards realistic tool statically detecti...
# 1         lifelong learning sentiment classification
# 2  improving price anarchy selfish routing via co...
# 3  finegrained incremental learning multifeature ...
# 4        urbanit visualizing repositories everywhere
